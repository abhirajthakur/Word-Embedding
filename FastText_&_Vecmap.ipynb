# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !head -200000 < /content/drive/MyDrive/fastext_vecmap/eng/eng.txt > /content/drive/MyDrive/eng.txt

# %%
# !head -200000 < /content/drive/MyDrive/fastext_vecmap/hi/hi.txt > /content/drive/MyDrive/hi.txt

# %%
# !head -100000 < /content/drive/MyDrive/fastext_vecmap/eng/eng.txt > /content/drive/MyDrive/eng.txt

# %%
# !head -100000 < /content/drive/MyDrive/fastext_vecmap/hi/hi.txt > /content/drive/MyDrive/hi.txt

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# # **FastText**

# %%
# !git clone https://github.com/facebookresearch/fastText.git
# Out:
# fatal: destination path 'fastText' already exists and is not an empty directory.

# %%
# %cd fastText
# Out:
# /content/drive/MyDrive/Colab Notebooks/fastText

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/fastText
# Out:
# /content/drive/MyDrive/Colab Notebooks/fastText

# %%
## Build using make
# !make
# Out:
# make: Nothing to be done for 'opt'.

# %%
## Build using Cmake
#!mkdir build && cd build && cmake ..
#!make && make install

# %%
# !chmod 755 fasttext

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab Notebooks/fastText'

# %%
#! ./fasttext skipgram -input input.txt -output output_txt -dim 300 -epoch 10
! ./fasttext skipgram -input /content/drive/MyDrive/fastext_vecmap/eng/eng.txt -output /content/drive/MyDrive/fastext_vecmap/en_ft-300D -dim 300 -epoch 10
# Out:
# Read 0M words
# Number of words:  4596
# Number of labels: 0
# Progress: 100.0% words/sec/thread:   14539 lr:  0.000000 avg.loss:  2.462999 ETA:   0h 0m 0s

# %%
#! ./fasttext skipgram -input input.txt -output output_txt -dim 300 -epoch 10
! ./fasttext skipgram -input /content/drive/MyDrive/fastext_vecmap/hi/hi.txt -output /content/drive/MyDrive/fastext_vecmap/hi_ft-300D -dim 300 -epoch 10
# Out:
# Read 0M words
# Number of words:  6564
# Number of labels: 0
# Progress: 100.0% words/sec/thread:    6383 lr:  0.000000 avg.loss:  1.989007 ETA:   0h 0m 0s

# %%
# %cd ..
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# # **VecMap**

# %%
# !git clone https://github.com/artetxem/vecmap
# Out:
# fatal: destination path 'vecmap' already exists and is not an empty directory.

# %%
# %cd vecmap
# Out:
# /content/drive/MyDrive/Colab Notebooks/vecmap

# %%
## Supervised 
python3 map_embeddings.py --supervised TRAIN.DICT SRC.EMB TRG.EMB SRC_MAPPED.EMB TRG_MAPPED.EMB
# Out:
#   File "<ipython-input-61-8aed47c27d6b>", line 2
#     python3 map_embeddings.py --supervised TRAIN.DICT SRC.EMB TRG.EMB SRC_MAPPED.EMB TRG_MAPPED.EMB
#             ^
# SyntaxError: invalid syntax

# %%
## Semi-supervised
python3 map_embeddings.py --semi_supervised TRAIN.DICT SRC.EMB TRG.EMB SRC_MAPPED.EMB TRG_MAPPED.EMB

# %%
## Identical
python3 map_embeddings.py --identical SRC.EMB TRG.EMB SRC_MAPPED.EMB TRG_MAPPED.EMB

# %%
## Unsupervised
#!python3 map_embeddings.py --unsupervised src_emb.vec trg_emb.vec SRC_MAPPED.EMB TRG_MAPPED.EMB --cuda
#src_emb.vec trg_emb.vec (these files are generated using fasttext)
#SRC_MAPPED.EMB TRG_MAPPED.EMB (these will be generated.... just provide the path/to/location/of/empty/file)
# !python3 map_embeddings.py --unsupervised /content/drive/MyDrive/fastext_vecmap/en_ft-300D.vec /content/drive/MyDrive/fastext_vecmap/en_ft-300D.vec /content/drive/MyDrive/fastext_vecmap/SRC_Mapped_Hi-KP.emb /content/drive/MyDrive/fastext_vecmap/TRG_Mapped_Hi-KP.emb --cuda

# %%
# !python3 eval_translation.py  /content/drive/MyDrive/DataAugment/nfr/eng_nfr.vec /content/drive/MyDrive/DataAugment/nfr/hin_nfr.vec -d /content/drive/MyDrive/Colab_Notebooks/vecmap/en_hi_with_5000_dictionary_word_model/TRAIN.DICT --retrieval nn
