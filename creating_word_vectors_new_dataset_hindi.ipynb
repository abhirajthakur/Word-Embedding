# %% [markdown]
# # Creating Word Vectors with word2vec

# %% [markdown]
# #### Install Dependencies

# %%
import nltk
from nltk.corpus.reader.plaintext import PlaintextCorpusReader
import gensim
from gensim.models.word2vec import Word2Vec
from sklearn.manifold import TSNE
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import show, figure

# %% [markdown]
# #### Load Data

# %%
corpus_root = 'C:\\Users\\abhir\\Desktop\\Minor Project\\corpus'

# %%
corpus = PlaintextCorpusReader(corpus_root, 'hi_40000.txt')

# %%
corpus_sents = corpus.sents()

# %% [markdown]
# #### Tokenize Text

# %%
len(corpus_sents)
# Out:
# 2936

# %%
corpus_sents[0:4]
# Out:
# [['भ',
#   'ा',
#   'रत',
#   'ी',
#   'य',
#   'क',
#   'ृ',
#   'ष',
#   'ि।',
#   'क',
#   'ृ',
#   'ष',
#   'ि',
#   'वह',
#   'कल',
#   'ा,',
#   'व',
#   'ि',
#   'ज',
#   '्',
#   'ञ',
#   'ा',
#   'न',
#   'और',
#   'उद',
#   '्',
#   'य',
#   'ो',
#   'ग',
#   'ह',
#   'ै',
#   'ज',
#   'ो',
#   'म',
#   'ा',
#   'नव',
#   'उपय',
#   'ो',
#   'ग',
#   'क',
#   'े',
#   'ल',
#   'ि',
#   'ए',
#   'प',
#   'ौ',
#   'ध',
#   'ों',
#   'और',
#   'पश',
#   'ु',
#   'ओ',
#   'ं',
#   'क',
#   'े',
#   'व',
#   'ि',
#   'क',
#   'ा',
#   'स',
#   'क',
#   'ा',
#   'प',
#   '्',
#   'रब',
#   'ं',
#   'ध',
#   'करत',
#   'ी',
#   'ह',
#   'ै।',
#   'म',
#   'ो',
#   'ट',
#   'े',
#   'त',
#   'ौ',
#   'र',
#   'पर',
#   'क',
#   'ृ',
#   'ष',
#   'ि',
#   'म',
#   'ें',
#   'भ',
#   'ू',
#   'म',
#   'ि',
#   'क',
#   'ी',
#   'ज',
#   'ु',
#   'त',
#   'ा',
#   'ई',
#   ',',
#   'फसल',
#   'ों',
#   'क',
#   'ी',
#   'र',
#   'ु',
#   'प',
#   'ा',
#   'ई',
#   'और',
#   'कट',
#   'ा',
#   'ई',
#   ',',
#   'पश',
#   'ु-',
#   'प',
#   '्',
#   'रजनन',
#   'और',
#   'प',
#   'ा',
#   'लन',
#   ',',
#   'द',
#   'ु',
#   'ग',
#   '्',
#   'ध',
#   '-',
#   'व',
#   '्',
#   'यवस',
#   'ा',
#   'य',
#   'और',
#   'वन',
#   'ी',
#   'करण',
#   'सम',
#   '्',
#   'म',
#   'ि',
#   'ल',
#   'ि',
#   'त',
#   'ह',
#   'ैं।',
#   'प',
#   '्',
#   'रत',
#   '्',
#   'य',
#   'े',
#   'क',
#   'मह',
#   'ा',
#   'द',
#   '्',
#   'व',
#   'ी',
#   'प',
#   ',',
#   'द',
#   'े',
#   'श',
#   ',',
#   'र',
#   'ा',
#   'ज',
#   '्',
#   'य',
#   'और',
#   'कन',
#   'ा',
#   'ड',
#   'ा',
#   'क',
#   'े',
#   'प',
#   '्',
#   'र',
#   'ां',
#   'त',
#   'ी',
#   'य',
#   'ल',
#   'े',
#   'ख',
#   'ों',
#   'म',
#   'ें',
#   'प',
#   '्',
#   'र',
#   'ा',
#   'द',
#   'े',
#   'श',
#   'ि',
#   'क',
#   'और',
#   'र',
#   'ा',
#   'ष',
#   '्',
#   'ट',
#   '्',
#   'र',
#   'ी',
#   'य',
#   'क',
#   'ृ',
#   'ष',
#   'ि',
#   'क',
#   'ा',
#   'व',
#   'ि',
#   'स',
#   '्',
#   'त',
#   'ा',
#   'र',
#   'स',
#   'े',
#   'वर',
#   '्',
#   'णन',
#   'क',
#   'ि',
#   'य',
#   'ा',
#   'गय',
#   'ा',
#   'ह',
#   'ै।',
#   'आध',
#   'ु',
#   'न',
#   'ि',
#   'क',
#   'क',
#   'ृ',
#   'ष',
#   'ि',
#   'बह',
#   'ु',
#   'त',
#   'हद',
#   'तक',
#   'अभ',
#   'ि',
#   'य',
#   'ां',
#   'त',
#   '्',
#   'र',
#   'ि',
#   'क',
#   'ी,',
#   'प',
#   '्',
#   'र',
#   'ौ',
#   'द',
#   '्',
#   'य',
#   'ो',
#   'ग',
#   'ि',
#   'क',
#   'ी',
#   'और',
#   'ज',
#   'ै',
#   'व',
#   'तथ',
#   'ा',
#   'भ',
#   'ौ',
#   'त',
#   'ि',
#   'क',
#   'व',
#   'ि',
#   'ज',
#   '्',
#   'ञ',
#   'ा',
#   'न',
#   'पर',
#   'न',
#   'ि',
#   'र',
#   '्',
#   'भर',
#   'करत',
#   'ी',
#   'ह',
#   'ै।',
#   'स',
#   'िं',
#   'च',
#   'ा',
#   'ई',
#   ',',
#   'जल',
#   '-',
#   'न',
#   'ि',
#   'क',
#   'ा',
#   'स',
#   ',',
#   'पर',
#   'ि',
#   'रक',
#   '्',
#   'षण',
#   ',',
#   'और',
#   'स',
#   '्',
#   'वच',
#   '्',
#   'छत',
#   'ा',
#   'अभ',
#   'ि',
#   'य',
#   'ां',
#   'त',
#   '्',
#   'र',
#   'ि',
#   'क',
#   'ी',
#   'म',
#   'ें',
#   'स',
#   'े',
#   'प',
#   '्',
#   'रत',
#   '्',
#   'य',
#   'े',
#   'क',
#   'सफल',
#   'ख',
#   'े',
#   'त',
#   'ी',
#   'क',
#   'े',
#   'ल',
#   'ि',
#   'ए',
#   'महत',
#   '्',
#   'वप',
#   'ू',
#   'र',
#   '्',
#   'ण',
#   'ह',
#   'ै।',
#   'स',
#   'िं',
#   'च',
#   'ा',
#   'ई',
#   ',',
#   'जल',
#   '-',
#   'न',
#   'ि',
#   'क',
#   'ा',
#   'स',
#   ',',
#   'पर',
#   'ि',
#   'रक',
#   '्',
#   'षण',
#   ',',
#   'और',
#   'स',
#   '्',
#   'वच',
#   '्',
#   'छत',
#   'ा',
#   'अभ',
#   'ि',
#   'य',
#   'ां',
#   'त',
#   '्',
#   'र',
#   'ि',
#   'क',
#   'ी',
#   'ऐस',
#   'े',
#   'क',
#   '्',
#   'ष',
#   'े',
#   'त',
#   '्',
#   'र',
#   'ह',
#   'ें',
#   'ज',
#   'ि',
#   'नम',
#   'ें',
#   'क',
#   'ृ',
#   'ष',
#   'ि',
#   'अभ',
#   'ि',
#   'य',
#   'ं',
#   'त',
#   'ा',
#   'ओ',
#   'ं',
#   'क',
#   'े',
#   'व',
#   'ि',
#   'श',
#   'ि',
#   'ष',
#   '्',
#   'ट',
#   'ज',
#   '्',
#   'ञ',
#   'ा',
#   'न',
#   'क',
#   'ी',
#   'आवश',
#   '्',
#   'यकत',
#   'ा',
#   'ह',
#   'ै।',
#   'क',
#   'ृ',
#   'ष',
#   'ि',
#   'रस',
#   'ा',
#   'यनश',
#   'ा',
#   'स',
#   '्',
#   'त',
#   '्',
#   'र',
#   'ख',
#   'े',
#   'त',
#   'ी',
#   'क',
#   'े',
#   'अन',
#   '्',
#   'य',
#   'महत',
#   '्',
#   'वप',
#   'ू',
#   'र',
#   '्',
#   'ण',
#   'क',
#   'ा',
#   'र',
#   '्',
#   'य',
#   'ों,',
#   'ज',
#   'ै',
#   'स',
#   'े',
#   'ख',
#   'ा',
#   'द',
#   ',',
#   'क',
#   'ी',
#   'टन',
#   'ा',
#   'शक',
#   'ों',
#   'और',
#   'फ़',
#   'ं',
#   'गसन',
#   'ा',
#   'शक',
#   'ों',
#   'क',
#   'े',
#   'उपय',
#   'ो',
#   'ग',
#   ',',
#   'भ',
#   'ू',
#   'म',
#   'ि',
#   'क',
#   'ी',
#   'त',
#   'ै',
#   'य',
#   'ा',
#   'र',
#   'ी,',
#   'क',
#   'ृ',
#   'ष',
#   'ि-',
#   'उत',
#   '्',
#   'प',
#   'ा',
#   'द',
#   'ों',
#   'क',
#   'ा',
#   'व',
#   'ि',
#   'श',
#   '्',
#   'ल',
#   'े',
#   'षण',
#   'और',
#   'ख',
#   'े',
#   'त',
#   'क',
#   'े',
#   'पश',
#   'ु',
#   'ओ',
#   'ं',
#   'क',
#   'ी',
#   'प',
#   'ो',
#   'षण',
#   '-',
#   'स',
#   'ं',
#   'ब',
#   'ं',
#   'ध',
#   'ी',
#   'आवश',
#   '्',
#   'यकत',
#   'ा',
#   'ओ',
#   'ं',
#   'स',
#   'े',
#   'स',
#   'ं',
#   'ब',
#   'ं',
#   'ध',
#   'ि',
#   'त',
#   'ह',
#   'ै।',
#   'वनस',
#   '्',
#   'पत',
#   'ि',
#   'प',
#   '्',
#   'रजनन',
#   'और',
#   'आन',
#   'ु',
#   'व',
#   'ां',
#   'श',
#   'ि',
#   'क',
#   'व',
#   'ि',
#   'ज',
#   '्',
#   'ञ',
#   'ा',
#   'न',
#   'ख',
#   'े',
#   'त',
#   'क',
#   'ी',
#   'उत',
#   '्',
#   'प',
#   'ा',
#   'दनश',
#   'ी',
#   'लत',
#   'ा',
#   'म',
#   'ें',
#   'भ',
#   'ा',
#   'र',
#   'ी',
#   'य',
#   'ो',
#   'गद',
#   'ा',
#   'न',
#   'द',
#   'े',
#   'त',
#   'े',
#   'ह',
#   'ैं।',
#   'आन',
#   'ु',
#   'व',
#   'ां',
#   'श',
#   'ि',
#   'क',
#   'व',
#   'ि',
#   'ज',
#   '्',
#   'ञ',
#   'ा',
#   'न',
#   'न',
#   'े',
#   'पश',
#   'ु-',
#   'प',
#   '्',
#   'रजनन',
#   'क',
#   'ो',
#   'भ',
#   'ी',
#   'एक',
#   'व',
#   'ि',
#   'ज',
#   '्',
#   'ञ',
#   'ा',
#   'न',
#   'बन',
#   'ा',
#   'द',
#   'ि',
#   'य',
#   'ा',
#   'ह',
#   'ै।',
#   'ह',
#   'ा',
#   'इड',
#   '्',
#   'र',
#   'ो',
#   'प',
#   'ो',
#   'न',
#   'ि',
#   'क',
#   '्',
#   'स',
#   'ब',
#   'ि',
#   'न',
#   'ा',
#   'म',
#   'ि',
#   'ट',
#   '्',
#   'ट',
#   'ी',
#   'क',
#   'े',
#   'ब',
#   'ा',
#   'गव',
#   'ा',
#   'न',
#   'ी',
#   'करन',
#   'े',
#   'क',
#   'ी',
#   'एक',
#   'व',
#   'ि',
#   'ध',
#   'ि',
#   'ह',
#   'ै।',
#   'इस',
#   'व',
#   'ि',
#   'ध',
#   'ि',
#   'स',
#   'े',
#   'प',
#   'ौ',
#   'ध',
#   'े',
#   'र',
#   'ा',
#   'स',
#   'ा',
#   'यन',
#   'ि',
#   'क',
#   'प',
#   'ो',
#   'षक',
#   'घ',
#   'ो',
#   'ल',
#   'ों',
#   'म',
#   'ें',
#   'उग',
#   'ा',
#   'ए',
#   'ज',
#   'ा',
#   'त',
#   'े',
#   'ह',
#   'ैं।',
#   'ह',
#   'ा',
#   'इड',
#   '्',
#   'र',
#   'ो',
#   'प',
#   'ो',
#   'न',
#   'ि',
#   'क',
#   '्',
#   'स',
#   'अध',
#   'ि',
#   'क',
#   'खद',
#   '्',
#   'य',
#   'ा',
#   'न',
#   '्',
#   'न',
#   'उत',
#   '्',
#   'प',
#   'ा',
#   'दन',
#   'क',
#   'ी',
#   'आवश',
#   '्',
#   'यकत',
#   'ा',
#   'क',
#   'ो',
#   'प',
#   'ू',
#   'र',
#   'ा',
#   'कर',
#   'सकत',
#   'ी',
#   'ह',
#   'ै',
#   'क',
#   '्',
#   'य',
#   'ों',
#   'क',
#   'ि',
#   'व',
#   'ि',
#   'श',
#   '्',
#   'व',
#   'क',
#   'ी',
#   'जनस',
#   'ं',
#   'ख',
#   '्',
#   'य',
#   'ा',
#   'बढ़',
#   'रह',
#   'ी',
#   'ह',
#   'ै।',
#   'क',
#   'ृ',
#   'ष',
#   'ी',
#   'य',
#   'उत',
#   '्',
#   'प',
#   'ा',
#   'द',
#   'ों',
#   'क',
#   'ी',
#   'प',
#   'ै',
#   'क',
#   'िं',
#   'ग',
#   ',',
#   'प',
#   '्',
#   'रक',
#   '्',
#   'र',
#   'ि',
#   'य',
#   'ा',
#   'और',
#   'ख़र',
#   'ी',
#   'द',
#   '-',
#   'फ़र',
#   'ो',
#   'ख',
#   '्',
#   'त',
#   'न',
#   'ि',
#   'कट',
#   'स',
#   'े',
#   'ज',
#   'ु',
#   'ड़',
#   'ी',
#   'ह',
#   'ु',
#   'ई',
#   'गत',
#   'ि',
#   'व',
#   'ि',
#   'ध',
#   'ि',
#   'य',
#   'ाँ',
#   'ह',
#   'ैं',
#   'ज',
#   'ो',
#   'व',
#   'ि',
#   'ज',
#   '्',
#   'ञ',
#   'ा',
#   'न',
#   'स',
#   'े',
#   'भ',
#   'ी',
#   'प',
#   '्',
#   'रभ',
#   'ा',
#   'व',
#   'ि',
#   'त',
#   'ह',
#   'ैं।',
#   'श',
#   'ी',
#   'घ',
#   '्',
#   'र',
#   '-',
#   'ह',
#   'ि',
#   'म',
#   'ी',
#   'करण',
#   'और',
#   'न',
#   'ि',
#   'र',
#   '्',
#   'जल',
#   'ी',
#   'करण',
#   'क',
#   'ी',
#   'व',
#   'ि',
#   'ध',
#   'ि',
#   'य',
#   'ों',
#   'न',
#   'े',
#   'ख',
#   'े',
#   'त',
#   '-',
#   'उत',
#   '्',
#   'प',
#   'ा',
#   'द',
#   'ों',
#   'क',
#   'ा',
#   'ब',
#   'ा',
#   'ज़',
#   'ा',
#   'र',
#   'बह',
#   'ु',
#   'त',
#   'बढ़',
#   'ा',
#   'द',
#   'ि',
#   'य',
#   'ा',
#   'ह',
#   'ै।',
#   'य',
#   'ं',
#   'त',
#   '्',
#   'र',
#   'ी',
#   'करण',
#   '१९व',
#   'ीं',
#   'शत',
#   'ा',
#   'ब',
#   '्',
#   'द',
#   'ी',
#   'क',
#   'े',
#   'अ',
#   'ं',
#   'त',
#   'और',
#   '२०व',
#   'ीं',
#   'शत',
#   'ा',
#   'ब',
#   '्',
#   'द',
#   'ी',
#   'क',
#   'ी',
#   'एक',
#   'उत',
#   '्',
#   'क',
#   'ृ',
#   'ष',
#   '्',
#   'ट',
#   ...],
#  ['स',
#   'े',
#   '१७',
#   ',',
#   '६८८',
#   'र',
#   'ु',
#   'प',
#   '्',
#   'रत',
#   'ि',
#   'ह',
#   'े',
#   'क',
#   '्',
#   'ट',
#   'े',
#   'यर',
#   '(',
#   '१९९६',
#   '-',
#   '९७',
#   'क',
#   'ी',
#   'क',
#   'ी',
#   'मत',
#   'ों',
#   'पर',
#   'आध',
#   'ा',
#   'र',
#   'ि',
#   'त',
#   '),',
#   'सकल',
#   'फसल',
#   'क',
#   '्',
#   'ष',
#   'े',
#   'त',
#   '्',
#   'र',
#   'क',
#   'ो',
#   '१९०',
#   '.',
#   '५',
#   'म',
#   'ि',
#   'ल',
#   'ि',
#   'यन',
#   'ह',
#   'े',
#   'क',
#   '्',
#   'ट',
#   'े',
#   'यर',
#   'स',
#   'े',
#   '१९९',
#   '.',
#   '३',
#   'म',
#   'ि',
#   'ल',
#   'ि',
#   'यन',
#   'ह',
#   'े',
#   'क',
#   '्',
#   'ट',
#   'े',
#   'यर',
#   'और',
#   'ख',
#   'ा',
#   'द',
#   'क',
#   'ी',
#   'खपत',
#   '१४',
#   '.',
#   '३४',
#   'स',
#   'े',
#   '२०',
#   '.',
#   '००',
#   'म',
#   'ि',
#   'ल',
#   'ि',
#   'यन',
#   'टन',
#   'बढ़',
#   'ा',
#   'न',
#   'े',
#   'क',
#   'ी',
#   'आवश',
#   '्',
#   'यकत',
#   'ा',
#   'ह',
#   'ै।',
#   'क',
#   'ु',
#   'ल',
#   'ब',
#   'ो',
#   'आई',
#   'क',
#   '्',
#   'ष',
#   'े',
#   'त',
#   '्',
#   'र',
#   'म',
#   'ें',
#   'व',
#   'ि',
#   'स',
#   '्',
#   'त',
#   'ा',
#   'र',
#   'क',
#   'ी',
#   'क',
#   'ो',
#   'ई',
#   'ग',
#   'ुं',
#   'ज',
#   'ा',
#   'इश',
#   'नह',
#   'ीं',
#   'ह',
#   'ै।',
#   'पश',
#   'ु-',
#   'प',
#   'ा',
#   'लन',
#   ',',
#   'ड',
#   'े',
#   'यर',
#   'ी,',
#   'और',
#   'मत',
#   '्',
#   'स',
#   '्',
#   'य',
#   '-',
#   'उद',
#   '्',
#   'य',
#   'ो',
#   'ग',
#   'ज',
#   'ै',
#   'स',
#   'े',
#   'अध',
#   'ि',
#   'क',
#   'उपज',
#   'क',
#   '्',
#   'ष',
#   'े',
#   'त',
#   '्',
#   'र',
#   'ों',
#   'म',
#   'ें',
#   'अध',
#   'ि',
#   'क',
#   'ध',
#   '्',
#   'य',
#   'ा',
#   'न',
#   'द',
#   'े',
#   'न',
#   'े',
#   'क',
#   'ी,',
#   'व',
#   'ि',
#   'पणन',
#   ',',
#   'स',
#   'ं',
#   'ग',
#   '्',
#   'रहण',
#   'और',
#   'व',
#   'ि',
#   'तरण',
#   'अवस',
#   'ं',
#   'रचन',
#   'ा',
#   'क',
#   'ो',
#   'ब',
#   'े',
#   'हतर',
#   'बन',
#   'ा',
#   'न',
#   'े,',
#   'उनक',
#   'ा',
#   'व',
#   'ि',
#   'स',
#   '्',
#   'त',
#   'ा',
#   'र',
#   'करन',
#   'े',
#   'और',
#   'स',
#   'ु',
#   'ध',
#   'ा',
#   'रन',
#   'े',
#   'क',
#   'ी',
#   'और',
#   'क',
#   'ृ',
#   'ष',
#   'ी',
#   'य',
#   'पण',
#   '्',
#   'य',
#   'ों',
#   'क',
#   'े',
#   'प',
#   'ा',
#   'र',
#   '्',
#   'सल',
#   'बन',
#   'ा',
#   'न',
#   'े,',
#   'श',
#   '्',
#   'र',
#   'े',
#   'ण',
#   'ी',
#   'करण',
#   'और',
#   'प',
#   '्',
#   'रम',
#   'ा',
#   'ण',
#   'ी',
#   'करण',
#   'करन',
#   'े',
#   'क',
#   'ी',
#   'स',
#   'ु',
#   'व',
#   'ि',
#   'ध',
#   'ा',
#   'ए',
#   'ँ',
#   'उपल',
#   '्',
#   'ब',
#   '्',
#   'ध',
#   'कर',
#   'ा',
#   'न',
#   'े',
#   'क',
#   'ी',
#   'आवश',
#   '्',
#   'यकत',
#   'ा',
#   'ह',
#   'ै।',
#   'क',
#   'ें',
#   'द',
#   '्',
#   'र',
#   'ी',
#   'य',
#   'य',
#   'ो',
#   'जन',
#   'ा',
#   'व',
#   '्',
#   'यय',
#   'बजट',
#   'म',
#   'ें',
#   'क',
#   'ृ',
#   'ष',
#   'ि',
#   'क',
#   'े',
#   'ल',
#   'ि',
#   'ए',
#   'न',
#   'ि',
#   'र',
#   '्',
#   'ध',
#   'ा',
#   'र',
#   'ि',
#   'त',
#   'स',
#   'िं',
#   'च',
#   'ा',
#   'ई',
#   'और',
#   'क',
#   'ृ',
#   'ष',
#   'ी',
#   'य',
#   'कर',
#   'ों',
#   'क',
#   'े',
#   'व',
#   '्',
#   'यय',
#   'क',
#   'ो',
#   '५८',
#   'प',
#   '्',
#   'रत',
#   'ि',
#   'शत',
#   'बढ़',
#   'ा',
#   'कर',
#   '१८०७',
#   'कर',
#   'ो',
#   'ड़',
#   'र',
#   'ु.'],
#  ['स', 'े', '२८५४', 'कर', 'ो', 'ड़', 'र', 'ु.'],
#  ['कर',
#   'द',
#   'ि',
#   'य',
#   'ा',
#   'गय',
#   'ा',
#   'थ',
#   'ा।',
#   '१९९८',
#   'म',
#   'ें',
#   'जलव',
#   'ि',
#   'भ',
#   'ा',
#   'जक',
#   'व',
#   'ि',
#   'क',
#   'ा',
#   'स',
#   'क',
#   'ा',
#   'र',
#   '्',
#   'यक',
#   '्',
#   'रम',
#   'ों',
#   'क',
#   'े',
#   'व',
#   '्',
#   'यय',
#   'क',
#   'ो',
#   '५१७',
#   'कर',
#   'ो',
#   'ड़',
#   'र',
#   'ु.']]

# %%
corpus_sents[5]
# Out:
# ['कर',
#  'द',
#  'ि',
#  'य',
#  'ा',
#  'गय',
#  'ा',
#  'थ',
#  'ा।',
#  'न',
#  'ि',
#  'ध',
#  'ि',
#  'य',
#  'ों',
#  'क',
#  'े',
#  'ब',
#  'े',
#  'हतर',
#  'इस',
#  '्',
#  'त',
#  'े',
#  'म',
#  'ा',
#  'ल',
#  'क',
#  'े',
#  'ल',
#  'ि',
#  'ए',
#  'व',
#  'ि',
#  'भ',
#  'ि',
#  'न',
#  '्',
#  'न',
#  'म',
#  'ं',
#  'त',
#  '्',
#  'र',
#  'ा',
#  'लय',
#  'ों',
#  'द',
#  '्',
#  'व',
#  'ा',
#  'र',
#  'ा',
#  'ल',
#  'ा',
#  'ग',
#  'ू',
#  'क',
#  'ि',
#  'ए',
#  'गए',
#  'सभ',
#  'ी',
#  'जलव',
#  'ि',
#  'भ',
#  'ा',
#  'जक',
#  'व',
#  'ि',
#  'क',
#  'ा',
#  'स',
#  'क',
#  'ा',
#  'र',
#  '्',
#  'यक',
#  '्',
#  'रम',
#  'ों',
#  'क',
#  'ो',
#  'एक',
#  'ी',
#  'क',
#  'ृ',
#  'त',
#  'करन',
#  'े',
#  'क',
#  'ा',
#  'प',
#  '्',
#  'रस',
#  '्',
#  'त',
#  'ा',
#  'व',
#  'थ',
#  'ा।',
#  'त',
#  '्',
#  'वर',
#  'ि',
#  'त',
#  'स',
#  'िं',
#  'च',
#  'ा',
#  'ई',
#  'क',
#  'ा',
#  'र',
#  '्',
#  'यक',
#  '्',
#  'रम',
#  'ों',
#  'क',
#  'े',
#  'ल',
#  'ि',
#  'ए',
#  'आब',
#  'ं',
#  'टन',
#  '२००',
#  'कर',
#  'ो',
#  'ड़',
#  'र',
#  'ु.']

# %%
len(corpus.words())
# Out:
# 922476

# %% [markdown]
# #### Run word2vec

# %%
# model = Word2Vec(sentences=corpus_sents, vector_size=64, sg=1, window=8, min_count=5)

# %%
# model.save('custom_new_hindi.model')

# %%
model = Word2Vec.load('custom_new_hindi.model')

# %%
model.wv['एक']
# Out:
# array([ 0.20857203, -0.22270279, -0.2560898 , -0.21753399,  0.5036713 ,
#        -0.15070176,  0.17251459, -0.10405535, -0.14545974,  0.49571353,
#         0.03276695, -0.42924044, -0.05158996, -0.14056358, -0.27309388,
#         0.12756969,  0.0140184 ,  0.00341998,  0.18374665, -0.19029234,
#        -0.10463416,  0.09287792,  0.70374566,  0.3268699 ,  0.06408378,
#         0.34374216, -0.04534185,  0.14964445, -0.33728227,  0.02147296,
#         0.28605545, -0.16910374, -0.0086903 , -0.12647425, -0.01963792,
#         0.2571017 ,  0.14552188,  0.38956535, -0.11469615,  0.18485516,
#         0.3739206 , -0.09912858, -0.03872923, -0.38929805,  0.01278281,
#         0.1575225 ,  0.37728727, -0.02652862, -0.21393444,  0.22781712,
#         0.06461149,  0.19061245,  0.04826821,  0.2845378 ,  0.26820952,
#         0.26340693,  0.16832854, -0.16362445,  0.08159723, -0.3285872 ,
#        -0.11495338, -0.1780081 , -0.00425161, -0.13907902], dtype=float32)

# %%
model.wv.most_similar('फन')
# Out:
# [('सहल', 0.9818563461303711),
#  ('चब', 0.9798926711082458),
#  ('थड', 0.9794549345970154),
#  ('अलस', 0.9792309999465942),
#  ('सहभ', 0.9784791469573975),
#  ('चप', 0.9774987101554871),
#  ('आकस', 0.9763882756233215),
#  ('कलव', 0.9763667583465576),
#  ('अमलत', 0.9760223627090454),
#  ('ठल', 0.975899338722229)]

# %% [markdown]
# #### Reduce word vector dimensionality with T-SNE

# %%
len(model.wv.key_to_index) # Words that met the criteria
# Out:
# 2194

# %%
X = model.wv[model.wv.key_to_index]

# %%
tsne = TSNE()

# %%
X_2d = tsne.fit_transform(X)

# %%
X_2d[0:5]
# Out:
# array([[-31.267056,  14.435461],
#        [-31.665245,  15.432334],
#        [-31.27835 ,  14.201794],
#        [-31.094366,  13.949045],
#        [-32.40465 ,  13.936923]], dtype=float32)

# %%
coords_df = pd.DataFrame(X_2d, columns=['x', 'y'])
coords_df['token'] = model.wv.key_to_index.keys() # टोकन

# %%
coords_df.head()
# Out:
#            x          y token
# 0 -31.267056  14.435461     ा
# 1 -31.665245  15.432334     ्
# 2 -31.278351  14.201794     ि
# 3 -31.094366  13.949045     क
# 4 -32.404652  13.936923     े

# %%
coords_df.to_csv('custom_new_hindi.csv', index=False)

# %% [markdown]
# #### Visulaize 2D representation of word vectors

# %%
coords_df = pd.read_csv('custom_new_hindi.csv')

# %%
_ = coords_df.plot.scatter('x', 'y', figsize=(12, 12), marker='.', s=10, alpha=0.5)

# %%
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
subset_df = coords_df.sample(n=1000)

# %%
p = figure(plot_width=800, plot_height=800)
_ = p.text(x=subset_df.x, y=subset_df.y, text=subset_df.token)

# %%
show(p)
# Out:
#   <div class="bk-root" id="d7ac5a37-9ab0-424f-bc76-a478b4cedd4f" data-root-id="1003"></div>
